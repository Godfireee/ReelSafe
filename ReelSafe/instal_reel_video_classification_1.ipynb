# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !rm -rf /content/sample_data/
# !pip install --upgrade --no-cache-dir gdown
# !gdown https://drive.google.com/uc?id=1JnrwGhpitOK4xWc8N58TgQ-eFZ_nK3lW
# !gdown https://drive.google.com/uc?id=1IxYjJg91RwpgE3TXBJN-A25bIAAK31TL
# !gdown https://drive.google.com/uc?id=1Xga8i8qFJ5eeJ7KYaVlHVIMa57DG9YjI
# !gdown https://drive.google.com/uc?id=1WOCPRSKwDzYi3FBJh5xKUWi2vcLUQVoT
# !gdown https://drive.google.com/uc?id=16PBdPVSTSdRNEZ1RqdJgiJuVrUMxtsdC
# !gdown https://drive.google.com/uc?id=1DWZNy7A7AOHQwHjfXBkMEcmGkdw5ArBf
# !gdown https://drive.google.com/uc?id=1pFm63cNuurT79c8mIZ25dwl7ftFcP8oT
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1JnrwGhpitOK4xWc8N58TgQ-eFZ_nK3lW
# From (redirected): https://drive.google.com/uc?id=1JnrwGhpitOK4xWc8N58TgQ-eFZ_nK3lW&confirm=t&uuid=3c7bc2e2-cb0b-4070-a4c2-41937cad55e4
# To: /content/1dec_45files.zip
# 100% 159M/159M [00:02<00:00, 67.1MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1IxYjJg91RwpgE3TXBJN-A25bIAAK31TL
# From (redirected): https://drive.google.com/uc?id=1IxYjJg91RwpgE3TXBJN-A25bIAAK31TL&confirm=t&uuid=f9e312f8-1fca-4d5a-92bf-92fa79553797
# To: /content/8dec_64files.zip
# 100% 295M/295M [00:02<00:00, 139MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Xga8i8qFJ5eeJ7KYaVlHVIMa57DG9YjI
# To: /content/done_7files.zip
# 100% 13.6M/13.6M [00:00<00:00, 72.5MB/s]
# Downloading...
# ...

# %%
# !mkdir -p dataset/explicit
# !mv /content/* dataset/explicit/.
# Out:
# mv: cannot move '/content/dataset' to a subdirectory of itself, 'dataset/explicit/./dataset'

# %%
# %cd /content/dataset/explicit
# !unzip /content/dataset/explicit/1dec_45files.zip
# !unzip /content/dataset/explicit/8dec_64files.zip
# !unzip /content/dataset/explicit/done_7files.zip
# !unzip /content/dataset/explicit/explicit_23files.zip
# !unzip /content/dataset/explicit/reels1.zip
# !unzip /content/dataset/explicit/reels2.zip
# !unzip /content/dataset/explicit/smoking_10files.zip
# %cd /content/
# Out:
# /content/dataset/explicit
# Archive:  /content/dataset/explicit/1dec_45files.zip
#   inflating: SaveInsta.App - 3240417021483345880.mp4
#   inflating: SaveInsta.App - 3242244761199679759.mp4
#   inflating: SaveInsta.App - 3243034841036909575_27953746084.mp4
#   inflating: SaveInsta.App - 3243246305965157564_63381890621.mp4
#   inflating: SaveInsta.App - 3243714678893739574_51393151480.mp4
#   inflating: SaveInsta.App - 3243863153179156029.mp4
#   inflating: SaveInsta.App - 3243995828535881903_2010590018.mp4
#   inflating: SaveInsta.App - 3244204069148975269_2089870598.mp4
#   inflating: SaveInsta.App - 3244651995284790716_48379624090.mp4
#   inflating: SaveInsta.App - 3244715763919246156_4559404685.mp4
#   inflating: SaveInsta.App - 3244737629961514788.mp4
#   inflating: SaveInsta.App - 3244757151762937090.mp4
#   inflating: SaveInsta.App - 3244778929015945898_1402039833.mp4
#   inflating: SaveInsta.App - 3244844038029186278_206385719.mp4
# ...

# %%
# !rm -rf /content/dataset/explicit/*.zip

# %%
# !gdown https://drive.google.com/uc?id=1rQ7fEffFhOVxqj9QE4ziof6MZuGw7An8
# !gdown https://drive.google.com/uc?id=14JgPiom-4xuG-udWLOLJxsmZX-yNLYzz
# !gdown https://drive.google.com/uc?id=1z7sqYW0olinWsnP2TTyvq1_Xvssf8Y0_
# !gdown https://drive.google.com/uc?id=1d2sbITiaHkTdpLUMYIHqS7B5P3dOhhZj
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1rQ7fEffFhOVxqj9QE4ziof6MZuGw7An8
# From (redirected): https://drive.google.com/uc?id=1rQ7fEffFhOVxqj9QE4ziof6MZuGw7An8&confirm=t&uuid=c394d6a1-b03d-4fa6-bee5-580fe52c67d7
# To: /content/1dec_ne_29files.zip
# 100% 240M/240M [00:01<00:00, 133MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=14JgPiom-4xuG-udWLOLJxsmZX-yNLYzz
# From (redirected): https://drive.google.com/uc?id=14JgPiom-4xuG-udWLOLJxsmZX-yNLYzz&confirm=t&uuid=8ac18535-1985-45dd-a61e-9e24e4ef797c
# To: /content/8dec_123files.zip
# 100% 383M/383M [00:03<00:00, 115MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1z7sqYW0olinWsnP2TTyvq1_Xvssf8Y0_
# From (redirected): https://drive.google.com/uc?id=1z7sqYW0olinWsnP2TTyvq1_Xvssf8Y0_&confirm=t&uuid=f38a6cd5-9340-4896-aca4-640a7c3e482a
# To: /content/aatkal_12files.zip
# 100% 160M/160M [00:02<00:00, 67.3MB/s]
# Downloading...
# ...

# %%
# %cd /content/dataset/normal
# !unzip /content/dataset/normal/1dec_ne_29files.zip
# !unzip /content/dataset/normal/8dec_123files.zip
# !unzip /content/dataset/normal/aatkal_12files.zip
# !unzip /content/dataset/normal/done_36files.zip
# %cd /content/
# Out:
# /content/dataset/normal
# Archive:  /content/dataset/normal/1dec_ne_29files.zip
#   inflating: SaveInsta.App - 3003588100764871693_11988321.mp4
#   inflating: SaveInsta.App - 3047106780680222482.mp4
#   inflating: SaveInsta.App - 3106390002103192565.mp4
#   inflating: SaveInsta.App - 3139372153919886698_27788329.mp4
#   inflating: SaveInsta.App - 3184477747438991063_1038734.mp4
#   inflating: SaveInsta.App - 3187257974393301399.mp4
#   inflating: SaveInsta.App - 3203363253529699020.mp4
#   inflating: SaveInsta.App - 3219906454094457711.mp4
#   inflating: SaveInsta.App - 3228808287792099724_23964973.mp4
#   inflating: SaveInsta.App - 3237297569405123525_58641451560.mp4
#   inflating: SaveInsta.App - 3241712602814487891.mp4
#   inflating: SaveInsta.App - 3243105126256784248_4023335.mp4
#   inflating: SaveInsta.App - 3246193699363184575_52165418.mp4
#   inflating: SaveInsta.App - 3246567231084716740_47612559972.mp4
#   inflating: SaveInsta.App - 3246674307831046568.mp4
# ...

# %%
# !rm -rf /content/dataset/normal/*.zip

# %%
import os
len(os.listdir('/content/dataset/explicit')),len(os.listdir('/content/dataset/normal'))
# Out:
# (185, 199)

# %%
th = 50

for vid in os.listdir('/content/dataset/explicit')[th:]:
    os.remove(os.path.join('/content/dataset/explicit',vid))

for vid in os.listdir('/content/dataset/normal')[th:]:
    os.remove(os.path.join('/content/dataset/normal',vid))

# %%
len(os.listdir('/content/dataset/explicit')),len(os.listdir('/content/dataset/normal'))
# Out:
# (50, 50)

# %%
# !mv "/content/dataset" /content/video_data

# %%
from IPython.display import HTML
from base64 import b64encode
from pathlib import Path

mp4 = open(sorted(list(Path('/content/video_data/explicit').iterdir()))[8],'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open(sorted(list(Path('/content/video_data/normal').iterdir()))[0],'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
os.listdir('/content/video_data')
# Out:
# ['normal', 'explicit']

# %%
import os
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 20

# Specify the directory containing the UCF50 dataset.
DATASET_DIR = "/content/video_data/"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ['explicit', 'normal']

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list = []

    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video.
        success, frame = video_reader.read()

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255

        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)

    # Release the VideoCapture object.
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []

    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):

        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')

        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

        # Iterate through all the files present in the files list.
        for file_name in files_list:

            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)

    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: explicit
# Extracting Data of Class: normal

# %%
features.shape
# Out:
# (100, 20, 64, 64, 3)

# %%
labels.shape
# Out:
# (100,)

# %%
type(features),type(labels)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
np.save('features.npy', features)
np.save('labels.npy', labels)

# %%
import shutil
from pathlib import Path

data_path = '/content/video_data'
n_samples = 5

Path('sample_vid_data').mkdir(parents=True, exist_ok=True)
for cls_folder in list(Path(data_path).iterdir()):
    dst = Path(Path('sample_vid_data')/cls_folder.stem)
    dst.mkdir(parents=True, exist_ok=True)
    for idx,sample in enumerate(list(cls_folder.iterdir())):
        src = sample
        shutil.copy(src,dst)
        if (idx+1) == n_samples:
            break

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mv "/content/sample_vid_data" "/content/features.npy" "/content/labels.npy" "/content/drive/MyDrive/projects/insta-reel/."
